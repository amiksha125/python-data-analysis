# %% [markdown]
# ## Arithmetic Operations

# %%
2 + 3 + 8
# Out:
# 13

# %%
99 - 76
# Out:
# 23

# %%
23.45 + -456.98
# Out:
# -433.53000000000003

# %%
100 / 7
# Out:
# 14.285714285714286

# %%
100 // 7
# get qoutient without decimal part
# Out:
# 14

# %%
100 % 7
# get remainder
# Out:
# 2

# %%
5 ** 6
# Out:
# 15625

# %% [markdown]
# Certain operators like / and * take precedence over other operators like + and -, you can use parenthesis to specify the order in which operations are performed

# %%
(2 + 4) * (23 - 7) / 4 ** 8
# Out:
# 0.00146484375

# %% [markdown]
# ## A grocery store sells a bag of ice for $1.25, and makes 20%  profit. If it sells 500 bags of ice, how much total profit does it makes ?
#
# cost of icebag ($) = 1.25
#
# profit margin = 20% = 0.2
#
# profit per bag = cost of a bag * profit margin  1.25 * 0.2
#
# No of bags = 500
#
# Total profit = no of bags * profit per bag = 500 * (.2 * 1.25)

# %%
500 * (.2 * 1.25)
# Out:
# 125.0

# %% [markdown]
# Its not clear by looking at the code what each value represents, we can give name to each oof the numbers byusing Python variable
#
# ## Variables: Variables are containers for storing data. The data stored within a variable is called its value.
#
# variable need to single words, not starting with numbers

# %%
cost_of_ice_bag = 1.25

# %%
profit_margin = .2

# %%
number_of_bags = 500

# %%
# you can check the value by typing its variable name in code cell
cost_of_ice_bag
number_of_bags
# Out:
# 500

# %%
profit_per_bag = cost_of_ice_bag * profit_margin
profit_per_bag
# Out:
# 0.25

# %%
total_profit = number_of_bags * profit_per_bag
total_profit
# You can use the same code by just chnaging the value of variable if values of prolem is changed
# Out:
# 125.0

# %% [markdown]
# If you don not assign a value to variable after defining you will get an error

# %%
revenue
# You can still proceed in jupitor if encountered err
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 revenue
#       2 # You can still proceed in jupitor if encountered err
#
# NameError: name 'revenue' is not defined

# %% [markdown]
# Let us print the result with friendly message using print function - built in python function.
#
# ### Function: A function is a reusable set of instructions. A function takes one or more input, performs operations and often returns an output. You can define your own functions in Python

# %%
print("The grocery store makes a total profit of $", total_profit)
# Out:
# The grocery store makes a total profit of $ 125.0

# %% [markdown]
# the print() is used to display information, the information to be displayed must be enclosed within quotaion else python will treat it as variable and print iits value, the separator between text to print and variable is ','.
#
# It can take more inputs such as text, numbers, variables, and functions.
#
# Using # character, we can add comments to our code. Comments and blank spaces are ignored by Python

# %% [markdown]
# ### Evaluating conditions using Python
#
# Apart from arithmetic , Python provide us a way for comparing numbers and variables by providing comparison operator.
# They take two operands
#
# operator
# ==             checks if operands are equals
#
# !=             checks if operands are not equal
#
# >              checks if left operand is greater than right
#
# <              checks if left operand is less than right
#
# >=             left greater than or equal to right?
#
# <=             left less than or  equal to right ?
#
# ### The result of these operators are True or False (uppercase T or F)

# %%
my_fav_number  = 5
my_least_fav_number = 9
neutral_number = 3

# %%
my_fav_number == 5
# Out:
# True

# %%
my_fav_number == my_least_fav_number
# Out:
# False

# %%
my_least_fav_number != my_fav_number
# Out:
# True

# %%
my_least_fav_number <= 9
# Out:
# True

# %%
my_least_fav_number < my_fav_number
# Out:
# False

# %%
is_ice_bag_expensive = cost_of_ice_bag >= 10
print("Is ice bag expensive ? ", is_ice_bag_expensive)
# Out:
# Is ice bag expensive ?  False

# %% [markdown]
# ### Combining conditions with logical operators
# and, or operates on two conditions and True / False values(booleans) whereas not operates on one.
#
# * and -> returns true if and only if both the conditions are true
#
# * or -> returns true if atleast one condition is true
#
# * not -> returns true if condition is false and vice versa.
#
# Markdown
#
# *italic*
# **bold**
# [this is a link](https....)
# ![](img url)

# %%
False or True
not False
# Out:
# True

# %% [markdown]
# ## Variables and Data types
#
# more on variables -> It is created using assignment operator (separate from == equility comparison operator) followed by value
#
# you can define multiple variables on a single line
#
# you can assign the same value to multiple variables by chaining multiple assignment operators
#
# you can change the value stored in a variable by simply assigning it
#
# #### naming conventions
#
# A variablename mustbe short and can only contain lowercase or uppercase letters, numbers or underscores.
#
# they cannot start with number
#
# variable names are case-sensitive meaning a_num and A_num are diffirent

# %%
color1, color2, color3 = "red", "green", "yellow"
color2
# Out:
# 'green'

# %%
color4 = color5 =  color6 = "magneta"
color6
# Out:
# 'magneta'

# %%
color6 = "black"
color6
# Out:
# 'black'

# %%
counter = 6
counter += 4
counter
# Out:
# 10

# %% [markdown]
# A variables type can be checked using *type()* function

# %%
print(type(color3))
print(type(is_ice_bag_expensive))
print(type(counter))
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'int'>

# %% [markdown]
# ### Built-In data types
#
# #### Primitives
# * Integer
# * Float
# * Boolean
# * String
# * None
#
# ##### Non-Primitives
# * List
# * Tuple
# * Set
# * Dictionary
#
# primitive data types represents single value while non premitivesare often called data structures or containers because they hold multiple peices of data together.

# %% [markdown]
# Integer -> represents positive / negative whole numbers, from -ve infinity to infinity. They should not include decimal points.
# They have type *int*
#
# there is no restriction of lowest of highest values on integers in Python

# %%
my_int = -87672683597413698084652657765398741256335
print(type(my_int))
# Out:
# <class 'int'>

# %% [markdown]
# Floats -> They are numbers with a decimal points. No limit onthe value of float or decimal points. Represented as type *float*

# %%
pi = 3.14159235748374934783484638463
type(pi)
# Out:
# float

# %% [markdown]
# *Note* A whole number is treated as a float if it is written with a decimal point. Any number with a decimal point whether its 0  is a float in Python'

# %%
a_num = 3.0
type(a_num)
# Out:
# float

# %%
another_float = 4.
type(another_float)
# Out:
# float

# %% [markdown]
# #### Floats can be converted into integer and vice versa using *float()* and *int()* functions. This operation is called type casting

# %%
int(a_num)
# Out:
# 3

# %%
float(counter)
# Out:
# 10.0

# %% [markdown]
# While performing arithmetic operations integers are automatically converted into floats if any of the operands is float.
#
# / operator will always returns float
#
# Use // if u want the result of diivision to be an int

# %%
type( 3 * 9.5)
# Out:
# float

# %%
type(4 * 3)
# Out:
# int

# %%
type(4 / 6)
# Out:
# float

# %%
type(11 // 2)
# Out:
# int

# %% [markdown]
# **Boolean**: Reprents two values True or False, they have type *bool*
#
# They are returned as a result of comparison operator

# %%
is_today_sunday = 2 < 3
is_today_sunday
# Out:
# True

# %% [markdown]
# Booleans are automatically converted into int when used in arithmetic operations
#
# *True* is to 1
# *False* is to 0

# %%
5 + True
# Out:
# 6

# %%
5 - False
# Out:
# 5

# %%
3. + True
# Out:
# 4.0

# %% [markdown]
# Any value can be converted to ab boolean using bool function
#
# The following values evaluate to false:
#  1. False itself
#  2. The int 0
#  3. The float 0.0
#  4. The empty value None
#  5. the empty text ""
#  6. the empty list []
#  7. The empty dictionary {}
#  8. the empty set set()
#  9. The empty tuple ()
#  10. The empty range range(0)
#
# Everything else evaluates to True

# %%
bool({})
# Out:
# False

# %% [markdown]
# #### **None**
#
# Includes a single value *None*. Used to indicate the absense of value. To declarre a variable whose value may be assigned later

# %%
nothing = None
type(nothing)
# Out:
# NoneType

# %% [markdown]
# #### **String**
#
# A string is used to present text. Strings must be surrounded using quotations(either single '' or double "").
# It is a string or sequence of chars
#
# They have the type *str*

# %%
today = "Today is Wednesday"
type(today)
# Out:
# str

# %% [markdown]
# You can use single quotes inside a string written in double quotes, and vice versa
#
# escape the single quote within string inside another single quotation by prefixing it with / to disable treating it as closing.
# Same for double quotation

# %%
my_fav_movie = 'One flew over the Cuckoo\'s nest'
my_fav_movie
# Out:
# "One flew over the Cuckoo's nest"

# %% [markdown]
# String created using a single or double quotes must begin and end on same line. To create multiline strings, use three string quotes '''' or """
#
# Line breaks are using \n

# %%
my_day = """Today I spent my day by travelling across village


where I found a small cute rabbit roaming around its mother

They call it as \"meru\" """

print(my_day)
#explore this
# Out:
# Today I spent my day by travelling across village
#
#
# where I found a small cute rabbit roaming around its mother
#
# They call it as "meru"

# %% [markdown]
# String despite of being a primitive has its own bunch of buil in functions
#
# Characters like \n and \(escaped) counted as a single character

# %%
multiline = """a
b"""

multiline
# Out:
# 'a\nb'

# %%
len(multiline)
# Out:
# 3

# %%
len(my_day)
# Out:
# 136

# %% [markdown]
# A string can be converted into list using *list()* function to show a collection of characters

# %%
list(today)
# Out:
# ['T',
#  'o',
#  'd',
#  'a',
#  'y',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'W',
#  'e',
#  'd',
#  'n',
#  'e',
#  's',
#  'd',
#  'a',
#  'y']

# %% [markdown]
# We can access individual characters within a string using [] indexing notation, can go from 0 to n - 1 where n is str length

# %%
today[15]
# Out:
# 'd'

# %% [markdown]
# #### You can access a part of string by providing a start:end range instead of a single index[]

# %%
today[5:18]
# Out:
# ' is Wednesday'

# %% [markdown]
# #### You can check whether the string contains some specific text using *in* operator

# %%
'day' in today
# Out:
# True

# %% [markdown]
# ##### Two or more strings can be concatinated using + operator

# %%
full_name = "Anshuja Gajbhiye"
greeting = "Welcome"
greeting + full_name
# Out:
# 'WelcomeAnshuja Gajbhiye'

# %%
greeting + " " + full_name + "!"
# Out:
# 'Welcome Anshuja Gajbhiye!'

# %% [markdown]
# Strings have multiple built-in methods that manipulates them
#   Methods : Methods are functions associated with data types. They are accessed using . notation eg *variable_name.method()*
#
# .lower(), .upper() or capitalize() are used to change the case of characters

# %%
"monday is my fav".capitalize() 
# Converts first character of sentense to uppercase
# Out:
# 'Monday is my fav'

# %%
"monday".upper()
# Out:
# 'MONDAY'

# %% [markdown]
# .replace() is used to replace a part of the string with another string.
#
# It takes portion to be replaced and replacement string as an argument
#
# Note that a new string is returned, the original one is not modified

# %%
another_day = "thursday".replace("thurs", "fri")
another_day
# Out:
# 'friday'

# %% [markdown]
# .split() method can be used to split a string into a list of strings based on character(delimeter) provided

# %%
"Sum,Mon,Tues,Wed,Fri,Sat,Sun".split(",")
# Out:
# ['Sum', 'Mon', 'Tues', 'Wed', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# .strip() is used to remove the whitespaces character from the beginning and end of a string

# %%
"      This contains extra spaces    ".strip()
# Out:
# 'This contains extra spaces'

# %% [markdown]
# *.format()* method is used to combine values of other data types such as float, nteger, boolean etc with Strings. It is often used to create output message to display.

# %%
output_template = """If a grocery store sells ice bag at $ {} per bag with a profit margin of $ {} %, 
then the total profit it makes by selling $ {} ice bag is $ {}"""

print(output_template)
# Out:
# If a grocery store sells ice bag at $ {} per bag with a profit margin of $ {} %,
# then the total profit it makes by selling $ {} ice bag is $ {}

# %%
#Inserting values into string using format
cost_of_ice_bag = 1.25
profit_margin = 0.2
number_of_bags = 500

total_profit = number_of_bags * profit_margin * cost_of_ice_bag
output_msg = output_template.format(cost_of_ice_bag, profit_margin * 100, number_of_bags, total_profit)

#always use print when """"
print(output_msg)
# Out:
# If a grocery store sells ice bag at $ 1.25 per bag with a profit margin of $ 20.0 %,
# then the total profit it makes by selling $ 500 ice bag is $ 125.0

# %% [markdown]
# Simpler way than format is to use string concating operator to combine string with other values,
# *Those values must be converted into string first using str() method*

# %%
"If a grocery store sells ice bag at "+ str(cost_of_ice_bag)+"per bag with a profit margin of" + str(profit_margin) + ", then the total profit it makes by selling $ "+str(number_of_bags)+" ice bag is $ "+str(total_profit)
# Out:
# 'If a grocery store sells ice bag at 1.25per bag with a profit margin of0.2, then the total profit it makes by selling $ 500 ice bag is $ 125.0'

# %% [markdown]
# str() takes any data value and convert it into string

# %% [markdown]
# String also   support comparison operators == nd !=

# %%
"Leo" == "John"
# Out:
# False

# %%
"John" != "Neo"
# Out:
# True

# %% [markdown]
# ### **List**
#
# A list is an ordered collection of values.
#
# List can hold values of different data types, and support operations like add, remove and chnage values.
#
# They have type *list*.
#
# Enclose a list of values in [ and ], separated by commas

# %%
fruits = ["apple", "banana", "grapes"]
fruits
# Out:
# ['apple', 'banana', 'grapes']

# %%
type(fruits)
# Out:
# list

# %% [markdown]
# A list can contain diff data types including another list -> list of list

# %%
a_list = [23, 'Hello', None, 3.67, fruits, 34 > 9]
a_list
# Out:
# [23, 'Hello', None, 3.67, ['apple', 'banana', 'grapes'], True]

# %%
empty_list = []

# %% [markdown]
# Similar to str, you can check the no of items in list using *len()*

# %%
print("Number of fruits: ", len(fruits))
# , is a separator
# Out:
# Number of fruits:  3

# %% [markdown]
# Access the elements of a list using the *index* of element, starting from the index 0

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes']

# %%
fruits[1]
# Out:
# 'banana'

# %% [markdown]
# index number can access any integer value, but positive values must be from 0 to len(list) - 1 else you get IndexError
#
# Negative indexing starts with -1 from end item to first item

# %%
fruits[-1]
# Out:
# 'grapes'

# %% [markdown]
# Index Slicing

# %%
a_list = [23, 'Hello', None, 3.67, fruits, 34 > 9]
a_list[2:6] # 6 is non inclusive , meaning only values at indx 2, 3, 4, 5
# Out:
# [None, 3.67, ['apple', 'banana', 'grapes'], True]

# %%
a_list[:4]
# Out:
# [23, 'Hello', None, 3.67]

# %%
a_list[-5: -3]
# Out:
# ['Hello', None]

# %%
a_list[-2: -6] # empty , cant access items in reverse
# Out:
# []

# %%
a_list[3:] # till last item
# Out:
# [3.67, ['apple', 'banana', 'grapes'], True]

# %% [markdown]
# Change the value at specific index using assignment operator

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes']

# %%
fruits[2] = "kiwi"
fruits
# Out:
# ['apple', 'banana', 'kiwi']

# %%
fruits[5] = "banana"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 fruits[5] = "banana"
#
# IndexError: list assignment index out of range

# %% [markdown]
# A new value can be added to the end of ist using *.append()* method of list

# %%
fruits.append("papaya")
fruits
# I ran it for 5 times more, more 5 papaya appended
# Out:
# ['apple',
#  'banana',
#  'kiwi',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya']

# %% [markdown]
# Instead of end, a new value can be inserted at a specific index using *.insert()*

# %%
fruits.insert(4, "Pineapple")
fruits
# Out:
# ['apple',
#  'banana',
#  'kiwi',
#  'papaya',
#  'Pineapple',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya']

# %% [markdown]
# You can remove element using *.remove()*

# %% [markdown]
# If a value has multiple instances then only first instance is removed

# %%
fruits.remove("papaya")
fruits
# Out:
# ['apple',
#  'banana',
#  'kiwi',
#  'Pineapple',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya']

# %% [markdown]
# To remove element from a specific index, use *.pop(index)* method

# %%
fruits.pop(5)
# Out:
# 'papaya'

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'kiwi',
#  'Pineapple',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya']

# %% [markdown]
# You can check id certain value isa part of list or not using *in* operator

# %%
"cheeku" in fruits
# Out:
# False

# %%
"kiwi" in fruits
# Out:
# True

# %% [markdown]
# To combine two or more list use + operator, this is called list concatination

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'kiwi',
#  'Pineapple',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya']

# %%
more_fruits = fruits + ["tomato", "guava"] + ["mango", "dates", "orange"]
more_fruits
# Out:
# ['apple',
#  'banana',
#  'kiwi',
#  'Pineapple',
#  'papaya',
#  'papaya',
#  'papaya',
#  'papaya',
#  'tomato',
#  'guava',
#  'mango',
#  'dates',
#  'orange']

# %% [markdown]
# To create a copy of list , use *.copy()* method

# %% [markdown]
# 1. reverse the order of elements in a list
#
#   using reverse() which reverse a list, reversed() does same but returns an iterator
#   using slicing [start: stop: step] = [ : : -1] python assumes starts to be end of list, stop to be beggining of list
#   step = -1, it tells how to move through list, if +1 then move forward(left to right), and if -1 then moves backward(right to left)
#   start from the end, move one step backward eac time and stop before begining

# %%
a_list.reverse()
a_list
# Out:
# [True,
#  ['apple',
#   'banana',
#   'kiwi',
#   'Pineapple',
#   'papaya',
#   'papaya',
#   'papaya',
#   'papaya'],
#  3.67,
#  None,
#  'Hello',
#  23]

# %%
fruits[: : -1]
# Out:
# ['papaya',
#  'papaya',
#  'papaya',
#  'papaya',
#  'Pineapple',
#  'kiwi',
#  'banana',
#  'apple']

# %% [markdown]
# 2. Add the element of one list to the end of the list

# %%
fruits.append(a_list[4])
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'Pineapple', 'papaya', 'papaya', 'papaya', 'papaya', 'Hello']

# %% [markdown]
# 3. Sort the list of strings in a alphabetical order
#
# Using .sort() method, list.sort(reverse = True) inplace sort it modifies the original list
# Using sorted function, sorted(list) which craates a new sorted list without modifying original

# %%
frt = ['apple', 'banana', 'kiwi', 'Pineapple', 'Pineapple', 'papaya']
frt.sort(reverse=False)
frt
# Out:
# ['Pineapple', 'Pineapple', 'apple', 'banana', 'kiwi', 'papaya']

# %%
new_frt = sorted(frt, reverse=True)
new_frt
# Out:
# ['papaya', 'kiwi', 'banana', 'apple', 'Pineapple', 'Pineapple']

# %% [markdown]
# 4. Sort the list of numbers in decsreasing order

# %%
num_list = [2, 3, 4, 5, 6]
num_list.sort(reverse=True)
num_list
# Out:
# [6, 5, 4, 3, 2]

# %% [markdown]
# #### **Tuple**
#
# A tuple is an ordered collection of values.
#
# Unlike list, tuples are immutable, It is not possible to add, remove , or odify values in tuples
#
# Created by enclosing values in paraenthesis ( and )
#
# Cannot be modifies after creation is called immutable, They are immutable list

# %%
fruits = ("apple", "mango", "banana")
type(fruits)
# Out:
# tuple

# %%
len(fruits)
# Out:
# 3

# %%
fruits[2]
# Out:
# 'banana'

# %%
"dats" in fruits
# Out:
# False

# %%
fruits.append("Blueberry") # less flexible than list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 fruits.append("Blueberry") # less flexible than list
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
single_element_tuple = 4, 
type(single_element_tuple)
# Out:
# tuple

# %%
new_tuple = tuple([2, 4, 'shhjh'])
new_tuple
# Out:
# (2, 4, 'shhjh')

# %%
print(list(new_tuple))
# Out:
# [2, 4, 'shhjh']

# %% [markdown]
# Tuple has two built in functions count and index.

# %%
# Out:
# Signature: a_list.count(value, /)
# Docstring: Return number of occurrences of value.
# Type:      builtin_function_or_method

# %% [markdown]
# #### **Dictionary**
#
# A dictionary is an unordered collection of items. Each item has a key and value. key are used to retrieve values from the dictionary so they must be unique.
#
# they have type *dict*, created byenclosing key-value pairs within { }
#
# keys are lookup table, they are strings, they are just like index pointing to value

# %%
person1 = {
    "name" : 'John Fisher',
    "sex": 'Male',
    "age" : 25,
    "married": True
}

person1
# Out:
# {'name': 'John Fisher', 'sex': 'Male', 'age': 25, 'married': True}

# %% [markdown]
# Dictionaries can also be created using *dict* function

# %%
person2 = dict(name = "Kiara Juel", sex = "female", age = 23, married = False)
person2
# Out:
# {'name': 'Kiara Juel', 'sex': 'female', 'age': 23, 'married': False}

# %%
type(person2)
# Out:
# dict

# %% [markdown]
# keys can be used to access values using square brackets [ "keyname" ]

# %%
person2["name"]
# Out:
# 'Kiara Juel'

# %%
person1['married']
# Out:
# True

# %% [markdown]
# the get method accepts a default value if the key is not presentin a dictionary

# %%
person1.get("address", "unknown")
# Out:
# 'unknown'

# %% [markdown]
# You can check if the key is present using in operator

# %%
'age' in person2
# Out:
# True

# %% [markdown]
# Change the value associated with key using assignment operator
#
# usingthe same you can add a new key value pair
# dict["newKey"] = "newValue"

# %%
person2['married'] = True
print(person2)
# Out:
# {'name': 'Kiara Juel', 'sex': 'female', 'age': 23, 'married': True}

# %%
person2['address'] = 'I, Penny lane'

# %%
person2
# Out:
# {'name': 'Kiara Juel',
#  'sex': 'female',
#  'age': 23,
#  'married': True,
#  'address': 'I, Penny lane'}

# %% [markdown]
# use .pop('key') to remove a key with its associated value

# %%
person2.pop('age')
person2
# Out:
# {'name': 'Kiara Juel',
#  'sex': 'female',
#  'married': True,
#  'address': 'I, Penny lane'}

# %% [markdown]
# Dicctionary buit - in methods to viiew thelist of keys, values or key-value pairs

# %%
person1.keys()
# Out:
# dict_keys(['name', 'sex', 'age', 'married'])

# %%
person1.values()
# Out:
# dict_values(['John Fisher', 'Male', 25, True])

# %%
person1.items()
# Out:
# dict_items([('name', 'John Fisher'), ('sex', 'Male'), ('age', 25), ('married', True)])

# %%
person1.items()[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 person1.items()[1]
#
# TypeError: 'dict_items' object is not subscriptable

# %% [markdown]
# 1. Keys must  be unique. If you attempt to create a dictionary with the same key multiple times, the value associated with the last ocuurance of key will overwrite prev value

# %%
my_dict = {
    "name" : "Taksha",
    "age": 20,
    "name": "Amiksha"
}

my_dict
# Out:
# {'name': 'Amiksha', 'age': 20}

# %% [markdown]
# 2. There are two methods for creating copy -> copy() created shallow copy means changes made to copy will affect the original.
#   deepcopy() method will create an independent copy.

# %%
copy_dict = my_dict.copy()

copy_dict['age'] = 22

copy_dict
# Out:
# {'name': 'Amiksha', 'age': 22}

# %%
my_dict
# Out:
# {'name': 'Amiksha', 'age': 20}

# %%
my_dict = copy_dict
my_dict # this is shallow copy , two ref pointing to same obj
# Out:
# {'name': 'Amiksha', 'age': 22}

# %% [markdown]
# The keys of the dictionary can be something other than string They can be number , tuple , boolean

# %%
dictionary = {
    1: "integer",
    3.24: "float",
    (2, 5): "tuple",
    True: "boolean"
}

print(dictionary[1])

print(dictionary[(2,5)])

print(dictionary[True])
# Out:
# boolean
# tuple
# boolean

# %% [markdown]
# How can you add the key value pairs from one dictionary into another dictionary

# %%
person1[list(person2.keys())[3]] = person2['address']
person1
# Out:
# {'name': 'John Fisher',
#  'sex': 'Male',
#  'age': 25,
#  'married': True,
#  'address': 'I, Penny lane'}
